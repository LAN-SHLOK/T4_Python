# %% [markdown]
# # MATPLOTLIB
# - A visualization library
# - Used to create plot and charts in python

# %% [markdown]
# ## import library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # LINE PLOT
# ```
# plt.plot
# Parameters -
# x,y = data values
# color = line color
# linestyle = style of line
# linewidth = thickness of line
# marker = point symbols
# markersize = size of marker
# ```

# %%
plt.plot?

# %%
x=[1,5,3,7]
y=[10,20,30,40]
plt.plot(
x,y,
color='red',
linestyle='--',
marker = 'o',
markersize=4
)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(
x,y,
color='pink',
linestyle='-',
marker = '^',
markersize=4
)
plt.title("A Line Plot")
plt.xlabel("X -axis")
plt.ylabel("Y -axis")
plt.grid(
True,
color="grey",
linestyle=":",
linewidth=1
)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
X=np.linspace(0,4*np.pi,1000)
Y=np.sin(X)
fig,ax = plt.subplots()
ax.plot(X,Y)
fig.show
Y=np.cos(X)
fig1,ax1 = plt.subplots()
ax1.plot(X,Y)
fig.show
# Out:
# <bound method Figure.show of <Figure size 432x288 with 1 Axes>>

# %%
plt.plot(X,Y)

# %%
X=np.linspace(0,10,100)
Y1,Y2=np.sin(X),np.cos(X)
ax.plot(X,Y1,X,Y2)

# %%
fig,(ax1,ax2)=plt.subplots(2,1)
ax1.plot(X,Y1,color="C1")
ax2.plot(X,Y2,color="C0")

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
ax1.plot(Y1,X,color="C1")
ax2.plot(Y2,X,color="C0")

# %% [markdown]
# # SUBPLOTS

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,30,40]
print(x,y)
# Out:
# [1, 2, 3, 4] [10, 20, 30, 40]

# %%
plt.subplot(1,2,1)
plt.plot(x,y,color="b")
plt.title("X vs Y")

plt.subplot(1,2,2)
plt.plot(y,x,color="orange")
plt.title("X vs Y")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(x,y,
           color="r",
           s=150,
           alpha=0.6)
plt.grid()

# %%
plt.show()

# %% [markdown]
# # BARPLOT

# %% [markdown]
# ## VERTICAL

# %%
plt.bar(x,y,color="g",width=0.5)
plt.show()

# %% [markdown]
# ## HORIZONTAL

# %%
plt.barh(x,y,color='r',height=0.6)
plt.show()

# %% [markdown]
# # Histogram

# %%
data = [10,20,30,40,50,69]
plt.hist(
data,
bins=5,
orientation='vertical',
align='mid')
# Out:
# (array([2., 1., 1., 1., 1.]),
#  array([10. , 21.8, 33.6, 45.4, 57.2, 69. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# # PIE CHART

# %%
labels = ['A','B','C']
sizes=[40,35,25]
colors=['r','b','g']
plt.pie(
sizes,
labels=labels,
colors=colors,
startangle=90,
autopct="%1.1f%%",
explode=[0,1,0]
)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 687. These cost categories applied to a $9.00 microcontroller:
# ```
# Engineering $1.35
# Manufacturing $3.60
# Sales $2.25
# Profit $1.80
# Create a  pie chart will show the cost breakdown as different sized pieces.
# ```

# %%
import matplotlib.pyplot as plt
categories = ['engg','mfg','sales','profit']
costs = [1.35,3.6,2.25,1.8]
totalcost = sum(costs)
percentages= [(cost/totalcost)*100 for cost in costs]
print(percentages)
plt.pie(
percentages,
labels=categories,
autopct="%1.1f%%"
)
plt.show
# Out:
# [15.000000000000002, 40.0, 25.0, 20.0]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 688. Here is how many students got each grade in the recent test:
# ```
# A- 4, B-12, C-10, D-2. Plot a pie chart for the student grades in the recent chart with different colors for each
# student grades and create a wedge for D. Also put a chart title as student's grade history
# ```

# %%
import matplotlib.pyplot as plt
categories = ['A','B','C','D']
students=[4,12,10,2]
plt.pie(
students,
labels=categories,
colors=["r","b","c","g"],
autopct="%1.1f%%"
)
# Out:
# ([<matplotlib.patches.Wedge at 0x2410fe86e80>,
# ...
#  [Text(0.9910657451172095, 0.47727213291294374, 'A'),
#   Text(-0.6858388280562522, 0.8600145940217683, 'B'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'C'),
#   Text(1.0724207353205284, -0.2447728874989573, 'D')],
#  [Text(0.5405813155184778, 0.2603302543161511, '14.3%'),
#   Text(-0.37409390621250116, 0.469098869466419, '42.9%'),
#   Text(5.61760540981606e-08, -0.5999999999999974, '35.7%'),
#   Text(0.5849567647202881, -0.13351248409034033, '7.1%')])

# %% [markdown]
# # 689. Imagine you survey your friends to find the kind of movie they like best: Comedy- 4, Action -5, Romance - 6, Drama -1, SciFi - 4. Plot a pie chart for the above survey and use different color for each analysis and create a wedge for action movies. Also put as chart title as "Survey analysis of movie

# %%
categories = ["Comedy","Action","Romance","Drama","SciFi"]
genre_no=[4,5,6,1,4]
plt.pie(
genre_no,
labels=categories,
colors=["r","b","c","g"],
autopct="%1.1f%%",
explode=[1,1,1,1,1]
)
plt.title("Survey Analysis of Movie")
# Out:
# Text(0.5, 1.0, 'Survey Analysis of Movie')

# %% [markdown]
# # 690. Create a Pie Chart using Python Program for the popularity data of different programming languages and displayed it as a pie chart using the Matplotlib Python library. For Python- 29, Java – 19, Javascript – 8, C# - 7, PHP – 6, C,C++ - 5, R – 3. Create an exploded view of python and show the % of each programming language in Pie Chart

# %%
popularity=[29,19,8,7,6,5,5,3]
Languages=["Python","Java","Javascript","C#","PHP","C","C++","R"]
plt.pie(
popularity,
labels=Languages,
colors=["r","b","c","g"],
autopct="%1.1f%%"
)
plt.title("Survey Analysis of Movie")
# Out:
# Text(0.5, 1.0, 'Survey Analysis of Movie')

# %% [markdown]
# # 691. Write a python program to create a bar plot of course v/s no. of students using the following dictionary with appropriate labels for X and Y axes and colour of the bars green.Data={‘C’:20,’C++’:15,’Java’:30,’Python’:35}

# %%
Data={"C":20,"C++":15,"Java":30,"Python":35}
courses=list(Data.keys())
Students=list((Data.values()))
plt.bar(

courses,
Students,
color='g'
)
plt.xlabel("Courses")
plt.ylabel("Studets")
# Out:
# Text(0, 0.5, 'Studets')

# %% [markdown]
# ## 692. Create a bar chart for the following dataset:
# ```
# Country = ['USA','Canada','Germany','UK','France']
# GDP_Per_Capita = [45000,42000,52000,49000,47000]. Also plot title, X-Axis, Y-Axis, different color for each country and
# the grid should be visible
# ```

# %%
Country = ['USA','Canada','Germany','UK','France']
GDP_Per_Capita = [45000,42000,52000,49000,47000]
plt.bar(
Country,
GDP_Per_Capita,
color='g'
)
plt.xlabel("Courses")
plt.ylabel("Studets")
# Out:
# Text(0, 0.5, 'Studets')

# %% [markdown]
# # 693. A Bar Chart to display employee id numbers on X-axis and their salaries as Y-axis in the form of a bar graph for two departments of a company. There are two departments like sales department and purchase department. For sales department their id's and salaries are mentioned as : x= [1001,1003,1006,1007,1009,1011] and y= [10000, 23000.50,18000.33,16500.5,12000.75, 9999.99] and for purchase department their id's and salaries are mentioned as: x=[100̣2,1004,1010,1008,1014,1015] and y=[ 5000,6000,4500.5,12000,9000,10000]. Make the chart title as "Microsoft Inc.", x-axis as emplyee id and Y axis as Salary. Use different colors for sales and purchase department.

# %%
x= [1001,1003,1006,1007,1009,1011]
y= [10000, 23000.50,18000.33,16500.5,12000.75, 9999.99]
plt.bar(
x,
y,
color='g'
)
plt.title("Microsoft Inc.")
plt.xlabel("Employee ID")
plt.ylabel("Salary")
plt.xlabel("Courses")
plt.ylabel("Studets")


x=[1002,1004,1010,1008,1014,1015]
y=[ 5000,6000,4500.5,12000,9000,10000]

plt.bar(
x,
y,
color='b'
)
plt.title("Microsoft Inc.")
plt.xlabel("Employee ID")
plt.ylabel("Salary")
plt.xlabel("Courses")
plt.ylabel("Studets")
# Out:
# Text(0, 0.5, 'Studets')
